# %%
import geopandas as gpd
from arcgis.features import GeoAccessor

gdf = gpd.read_file("../data/raw/accidentologie0.geojson")
sdf = GeoAccessor.from_geodataframe(gdf)

# %%
sdf.head()
# Out:
#   idusager       annee     pv  com_arm_code        victime_type   categorie  \
# 0  1887571  2018-03-02   1863         75117             4 Roues    Passager
# 1   189282  2021-06-22   4871         75113  2 Roues Motorisées  Conducteur
# 2  1905304  2018-11-22  11883         75112              Piéton      Piéton
# 3  1907825  2018-04-17   3593         75115             4 Roues  Conducteur
# 4  1911196  2018-09-25   9487         75115  2 Roues Motorisées  Conducteur
#
#         gravite   age sexe_victime  milieu  ... blesses_legers  \
# 0  Blessé léger  36.0      Feminin  En-Agg  ...            1.0
# 1  Blessé léger  17.0     Masculin  En-Agg  ...            1.0
# 2  Blessé léger  59.0     Masculin  En-Agg  ...            1.0
# 3  Blessé léger  33.0     Masculin  En-Agg  ...            1.0
# 4  Blessé léger  31.0     Masculin  En-Agg  ...            1.0
#
#   blesses_hospitalises tues  \
# 0                  NaN  NaN
# 1                  NaN  NaN
# 2                  NaN  NaN
# ...

# %%
sdf.columns
# Out:
# Index(['idusager', 'annee', 'pv', 'com_arm_code', 'victime_type', 'categorie',
#        'gravite', 'age', 'sexe_victime', 'milieu', 'adresse', 'champ13',
#        'longitude', 'latitude', 'id_accident', 'pim_bp', 'tranche_age_victime',
#        'blesses_legers', 'blesses_hospitalises', 'tues', 'resume',
#        'coordonnees', 'nom_arrondissement', 'arronco', 'coordonnes', 'iris',
#        'SHAPE'],
#       dtype='object')

# %%
sdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41211 entries, 0 to 41210
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   idusager              41211 non-null  object
#  1   annee                 41211 non-null  object
#  2   pv                    41211 non-null  object
#  3   com_arm_code          41211 non-null  int64
#  4   victime_type          41211 non-null  object
#  5   categorie             41211 non-null  object
#  6   gravite               41211 non-null  object
#  7   age                   41211 non-null  float64
#  8   sexe_victime          41211 non-null  object
#  9   milieu                41211 non-null  object
#  10  adresse               41209 non-null  object
#  11  champ13               41211 non-null  object
#  12  longitude             41211 non-null  object
#  13  latitude              41211 non-null  object
#  14  id_accident           41211 non-null  object
# ...

# %%
sdf.to_parquet("../data/raw/paris_accidents_raw.parquet")
